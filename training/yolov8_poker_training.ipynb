# %% [markdown]
# # Pull in Dataset

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="-------") # Input your own API key here
project = rf.workspace("birds-ntdtk").project("cards-2nrba")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Cards-3 in yolov5pytorch:: 100%|██████████| 3992/3992 [00:00<00:00, 5390.89it/s]

# %% [markdown]
# ### Convert to YOLO format

# %%
# Move folder structure to fit YOLOv5 format
import shutil

shutil.move('Cards-3/train',
            'Cards-3/Cards-3/train')

shutil.move('Cards-3/test',
            'Cards-3/Cards-3/test')

shutil.move('Cards-3/valid',
            'Cards-3/Cards-3/valid')
# Out:
# 'Cards-3/Cards-3/valid'

# %% [markdown]
# # Custom Training

# %%
dataset.location
# Out:
# '/content/Cards-3'

# %%
# !yolo task=detect mode=train model=yolov5mu.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ...
# 100% 48.2M/48.2M [00:00<00:00, 194MB/s]
# Ultralytics YOLOv8.2.24 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
